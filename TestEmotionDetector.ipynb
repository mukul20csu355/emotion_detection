# %%
import cv2
import numpy as np
from keras.models import model_from_json


emotion_dict = {0: "Angry", 1: "Disgusted", 2: "Fearful", 3: "Happy", 4: "Neutral", 5: "Sad", 6: "Surprised"}

# load json and create model
json_file = open('model/emotion_model.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
emotion_model = model_from_json(loaded_model_json)

# load weights into new model
emotion_model.load_weights("model/emotion_model.h5")
print("Loaded model from disk")

# start the webcam feed
cap = cv2.VideoCapture(0)

# pass here your video path
# you may download one from here : https://www.pexels.com/video/three-girls-laughing-5273028/
#cap = cv2.VideoCapture("C:\\JustDoIt\\ML\\Sample_videos\\emotion_sample6.mp4")

while True:
    # Find haar cascade to draw bounding box around face
    ret, frame = cap.read()
    frame = cv2.resize(frame, (1280, 720))  
    if not ret:
        break
    face_detector = cv2.CascadeClassifier('haarcascades/haarcascade_frontalface_default.xml')
    gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY) # Coverting the captured frame into gray frame

    # detect faces available on camera
    num_faces = face_detector.detectMultiScale(gray_frame, scaleFactor=1.3, minNeighbors=5)

    # take each face available on the camera and Preprocess it
    for (x, y, w, h) in num_faces:
        cv2.rectangle(frame, (x, y-50), (x+w, y+h+10), (0, 255, 0), 4) # Rectangle formation
        roi_gray_frame = gray_frame[y:y + h, x:x + w] 
        cropped_img = np.expand_dims(np.expand_dims(cv2.resize(roi_gray_frame, (48, 48)), -1), 0) # crop the image

        # predict the emotions
        emotion_prediction = emotion_model.predict(cropped_img) # pass the cropped image into the model for prediction
        maxindex = int(np.argmax(emotion_prediction)) # returns the index having larger value of confidence 
        cv2.putText(frame, emotion_dict[maxindex], (x+5, y-20), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, 0), 2, cv2.LINE_AA) # Put the text of the emotion

    cv2.imshow('Emotion Detection', frame)
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 3
#       1 import cv2
#       2 import numpy as np
# ----> 3 from keras.models import model_from_json
#       6 emotion_dict = {0: "Angry", 1: "Disgusted", 2: "Fearful", 3: "Happy", 4: "Neutral", 5: "Sad", 6: "Surprised"}
#       8 # load json and create model
#
# File c:\Users\mukul\Desktop\project emo\myenv\lib\site-packages\keras\__init__.py:20
#       1 # Copyright 2015 The TensorFlow Authors. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      13 # limitations under the License.
#      14 # ==============================================================================
#      15 """Implementation of the Keras API, the high-level API of TensorFlow.
#      16
#      17 Detailed documentation and user guides are available at
#      18 [keras.io](https://keras.io).
#      19 """
# ---> 20 from keras import distribute
#      21 from keras import models
#      22 from keras.engine.input_layer import Input
#
# File c:\Users\mukul\Desktop\project emo\myenv\lib\site-packages\keras\distribute\__init__.py:18
#       1 # Copyright 2019 The TensorFlow Authors. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      13 # limitations under the License.
#      14 # ==============================================================================
#      15 """Keras' Distribution Strategy library."""
# ---> 18 from keras.distribute import sidecar_evaluator
#
# File c:\Users\mukul\Desktop\project emo\myenv\lib\site-packages\keras\distribute\sidecar_evaluator.py:17
#       1 # Copyright 2020 The TensorFlow Authors. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      13 # limitations under the License.
#      14 # ==============================================================================
#      15 """Python module for evaluation loop."""
# ---> 17 import tensorflow.compat.v2 as tf
#      19 # isort: off
#      20 from tensorflow.python.platform import tf_logging as logging
#
# File c:\Users\mukul\Desktop\project emo\myenv\lib\site-packages\tensorflow\__init__.py:45
#      42 from tensorflow.python import tf2 as _tf2
#      43 _tf2.enable()
# ---> 45 from ._api.v2 import __internal__
#      46 from ._api.v2 import __operators__
#      47 from ._api.v2 import audio
#
# File c:\Users\mukul\Desktop\project emo\myenv\lib\site-packages\tensorflow\_api\v2\__internal__\__init__.py:8
#       3 """Public API for tf.__internal__ namespace.
#       4 """
#       6 import sys as _sys
# ----> 8 from . import autograph
#       9 from . import decorator
#      10 from . import dispatch
#
# File c:\Users\mukul\Desktop\project emo\myenv\lib\site-packages\tensorflow\_api\v2\__internal__\autograph\__init__.py:8
#       3 """Public API for tf.__internal__.autograph namespace.
#       4 """
#       6 import sys as _sys
# ----> 8 from tensorflow.python.autograph.core.ag_ctx import control_status_ctx
#       9 from tensorflow.python.autograph.impl.api import tf_convert
#
# File c:\Users\mukul\Desktop\project emo\myenv\lib\site-packages\tensorflow\python\autograph\core\ag_ctx.py:21
#      18 import inspect
#      19 import threading
# ---> 21 from tensorflow.python.autograph.utils import ag_logging
#      22 from tensorflow.python.util.tf_export import tf_export
#      25 stacks = threading.local()
#
# File c:\Users\mukul\Desktop\project emo\myenv\lib\site-packages\tensorflow\python\autograph\utils\__init__.py:17
#       1 # Copyright 2016 The TensorFlow Authors. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      13 # limitations under the License.
#      14 # ==============================================================================
#      15 """Utility module that contains APIs usable in the generated code."""
# ---> 17 from tensorflow.python.autograph.utils.context_managers import control_dependency_on_returns
#      18 from tensorflow.python.autograph.utils.misc import alias_tensors
#      19 from tensorflow.python.autograph.utils.tensor_list import dynamic_list_append
#
# File c:\Users\mukul\Desktop\project emo\myenv\lib\site-packages\tensorflow\python\autograph\utils\context_managers.py:19
#      15 """Various context managers."""
#      17 import contextlib
# ---> 19 from tensorflow.python.framework import ops
#      20 from tensorflow.python.ops import tensor_array_ops
#      23 def control_dependency_on_returns(return_value):
#
# File c:\Users\mukul\Desktop\project emo\myenv\lib\site-packages\tensorflow\python\framework\ops.py:49
#      47 # pylint: enable=invalid-import-order,g-bad-import-order,unused-import
#      48 from tensorflow.python import tf2
# ---> 49 from tensorflow.python.client import pywrap_tf_session
#      50 from tensorflow.python.eager import context
#      51 from tensorflow.python.eager import core
#
# File c:\Users\mukul\Desktop\project emo\myenv\lib\site-packages\tensorflow\python\client\pywrap_tf_session.py:25
#      22 from tensorflow.python.client._pywrap_tf_session import _TF_NewSessionOptions
#      24 # Register pybind11 type caster for StackTraceWrapper/AbstractStackTrace
# ---> 25 from tensorflow.python.util import tf_stack
#      27 # Convert versions to strings for Python2 and keep api_compatibility_test green.
#      28 # We can remove this hack once we remove Python2 presubmits. pybind11 can only
#      29 # return unicode for Python2 even with py::str.
#      30 # https://pybind11.readthedocs.io/en/stable/advanced/cast/strings.html#returning-c-strings-to-python
#      31 # pylint: disable=undefined-variable
#      32 __version__ = str(get_version())
#
# File c:\Users\mukul\Desktop\project emo\myenv\lib\site-packages\tensorflow\python\util\tf_stack.py:21
#      18 import inspect
#      19 import threading
# ---> 21 from tensorflow.core.framework import graph_debug_info_pb2
#      22 from tensorflow.python.util import _tf_stack
#      24 # Generally such lookups should be done using `threading.local()`. See
#      25 # https://blogs.gnome.org/jamesh/2008/06/11/tls-python/ for a detailed
#      26 # explanation of why. However the transform stacks are expected to be empty
#      27 # when a thread is joined, so reusing the key does not introduce a correctness
#      28 # issue. Moreover, get_ident is faster than storing and retrieving a unique
#      29 # key in a thread local store.
#
# File c:\Users\mukul\Desktop\project emo\myenv\lib\site-packages\tensorflow\core\framework\graph_debug_info_pb2.py:5
#       1 # -*- coding: utf-8 -*-
#       2 # Generated by the protocol buffer compiler.  DO NOT EDIT!
#       3 # source: tensorflow/core/framework/graph_debug_info.proto
#       4 """Generated protocol buffer code."""
# ----> 5 from google.protobuf.internal import builder as _builder
#       6 from google.protobuf import descriptor as _descriptor
#       7 from google.protobuf import descriptor_pool as _descriptor_pool
#
# ImportError: cannot import name 'builder' from 'google.protobuf.internal' (c:\Users\mukul\Desktop\project emo\myenv\lib\site-packages\google\protobuf\internal\__init__.py)
